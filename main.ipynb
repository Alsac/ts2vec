# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import arff

# %%
plt.plot(np.random.randn(10,3))
plt.show()

# %%
# data = arff.loadarff(r'D:\home\GitHub\ts2vec\datasets\UCR\BirdChicken\BirdChicken_TEST.tsv')
data = pd.read_csv(r'D:\home\GitHub\ts2vec\datasets\UCR\BirdChicken\BirdChicken_TEST.tsv', sep='\t')

# %%
plt.plot(data.iloc[:,1])
plt.show()

# %%
for i in range(data.shape[0]):#
    plt.plot(data.iloc[i,:])
    plt.show()
# data

# %%
data
# Out:
#     1  1.4551033  1.419576  1.3845511   1.35004  1.3160572  1.2590237  \
# 0   1   1.801297  1.756911   1.712960  1.645959   1.599261   1.552969
# 1   1   1.840091  1.856962   1.874598  1.897702   1.917021   1.898525
# 2   1   1.018825  1.055041   1.066801  1.026366   0.986560   0.937609
# 3   1   1.026523  1.008095   0.958907  0.925871   0.893706   0.830755
# 4   1   0.927302  0.943321   0.939952  0.933973   0.889483   0.801764
# 5   1   0.895769  0.846135   0.797468  0.740751   0.684322   0.619751
# 6   1   1.879463  1.825115   1.792514  1.741866   1.694725   1.651560
# 7   1   0.127359  0.123383   0.089394  0.077379   0.044375   0.064467
# 8   1   1.593471  1.554265   1.496179  1.457951   1.417550   1.353724
# 9   2   0.615667  0.620514   0.579302  0.510806   0.416455   0.364623
# 10  2   1.840119  1.799183   1.718605  1.678989   1.639826   1.591715
# 11  2   0.972551  0.963088   0.946815  0.940012   0.934115   0.872343
# ...

# %%
data = arff.loadarff(r'D:\home\GitHub\ts2vec\datasets\UEA\InsectWingbeat\InsectWingbeat_TEST.arff')
df = pd.DataFrame(data[0])

# %%
df
# Out:
#                                            relationalAtt            target
# 0      [[-0.002947, -0.053421, -0.049052, 0.046457, -...   b'Aedes_female'
# 1      [[5e-06, 0.006422, 0.852806, -3.11502, 2.89805...   b'Aedes_female'
# 2      [[0.000449, 0.036275, -0.602653, 0.896783, -5....   b'Aedes_female'
# 3      [[0.000866, 0.000288, -0.000149, 0.077175, -1....   b'Aedes_female'
# 4      [[0.000225, 0.000467, 0.003916, -0.094004, -0....   b'Aedes_female'
# ...                                                  ...               ...
# 24995  [[-0.004949, 0.000215, -0.081967, -0.075714, 0...  b'Tarsalis_male'
# 24996  [[-0.018081, 0.772809, 0.066242, -0.08282, 0.4...  b'Tarsalis_male'
# 24997  [[-1e-05, -0.529555, -0.197665, -1.451169, 0.7...  b'Tarsalis_male'
# 24998  [[1.769829, -6.348435, 5.379541, 2.392035, -11...  b'Tarsalis_male'
# 24999  [[0.000253, -0.013903, -0.748005, -1.286651, -...  b'Tarsalis_male'
#
# [25000 rows x 2 columns]

# %%
data[1]
# Out:
# Dataset: InsectWingbeat
# 	relationalAtt's type is relational
# 	target's type is nominal, range is ('Aedes_female', 'Aedes_male', 'Fruit_flies', 'House_flies', 'Quinx_female', 'Quinx_male', 'Stigma_female', 'Stigma_male', 'Tarsalis_female', 'Tarsalis_male')

# %%
set(df.target.values)
# Out:
# {b'Aedes_female',
#  b'Aedes_male',
#  b'Fruit_flies',
#  b'House_flies',
#  b'Quinx_female',
#  b'Quinx_male',
#  b'Stigma_female',
#  b'Stigma_male',
#  b'Tarsalis_female',
#  b'Tarsalis_male'}

# %%
df_aedes = df[df.target==b'Aedes_male']

# %%
df_aedes.relationalAtt.values[3][2]
# Out:
# (-0.121976, 0.687963, -0.51675, -4.370493, 0.364582, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan)
